# %%
import random
from IPython.display import clear_output

import csv
words = []
with open('words.csv', 'rb') as f:
    reader = csv.reader(f)
    for i in f:
        words.append(i.split('\n')[0])


all_words = a+a+a

while True:
    print(len(all_words))
    if len(all_words)==0:
        print('You did it man!! cheer up')
        break
    one = random.choice(all_words)
    word = one.split('-')[0]
    meaning = one.split('-')[1]
    print(word)
    take = raw_input('Press enter to show the meaning')
    if take == '':
        print(meaning)
        take = raw_input('Did you knew it(y/n)')
    if take== 'y':
        all_words.remove(one)
        
    clear_output()
# Out:
# set(['criticize/criticism', 'Funny', 'Unusual', 'Nag', 'Hesitate', 'beginning/young', 'bold', 'Timid/Timidity', 'bad mood', 'Truth', 'biting', 'disgusting/offensive', 'difficult_to_understand', 'Innocent/Inexperienced', 'Time/Order/Duration', 'Harsh', 'Poor', 'Pleasant', 'Sorrow', 'Greedy', 'Wisdom', 'Harmful', 'Smart/Learned', 'easy_to_understand', 'Lazy/Sluggish', 'Nasty', 'Overblown/Wordy', 'self_denail', 'Hostile', 'abbreviated', 'dictatorial', 'Healthy', 'death/mourning', 'assist', 'Gaps/Openings', 'Generous/Kind', 'Pacify/Satisfy', 'Withdrawal/Retreat', 'Praise', 'Act Quickly', 'Forgive/Make_Amends', 'Hatred', 'copy', 'Wandering', 'changing Quickly', 'Luck', 'Stubborn', 'Predict', 'boring', 'Hard', 'Investigate', 'Terse', 'Insincere', 'Prevent/Obstruct', 'Not_a_Straight_Line', 'wicked', 'beginner/amature', 'Weaken'])
# 1413
# veracious

# %%
# Out:
# <open file 'words.csv', mode 'rb' at 0x7fef20059f60>
# ['absolve-Forgive/Make_Amends',
#  'acquit-Forgive/Make_Amends',
#  'ameliorate-Forgive/Make_Amends',
#  'exculpate-Forgive/Make_Amends',
#  'exonerate-Forgive/Make_Amends',
#  'expiate-Forgive/Make_Amends',
#  'palliate-Forgive/Make_Amends',
#  'redress-Forgive/Make_Amends',
#  'vindicate-Forgive/Make_Amends',
#  'chortle-Funny',
#  'droll-Funny',
#  'facetious-Funny',
#  'flippant-Funny',
#  'gibe-Funny',
#  'jocular-Funny',
#  'levity-Funny',
#  'ludicrous-Funny',
#  'raillery-Funny',
#  'riposte-Funny',
#  'abatement-Gaps/Openings',
#  'aperture-Gaps/Openings',
#  'fissure-Gaps/Openings',
#  'hiatus-Gaps/Openings',
#  'interregnum-Gaps/Openings',
#  'interstice-Gaps/Openings',
#  'lull-Gaps/Openings',
#  'orifice-Gaps/Openings',
#  'rent-Gaps/Openings',
#  'respite-Gaps/Openings',
#  'rift-Gaps/Openings',
#  'altruistic-Generous/Kind',
#  'beneficent-Generous/Kind',
#  'clement-Generous/Kind',
#  'largess-Generous/Kind',
# ...

# %%
# Out:
# ['absolve-Forgive/Make_Amends',
#  'acquit-Forgive/Make_Amends',
#  'ameliorate-Forgive/Make_Amends',
#  'exculpate-Forgive/Make_Amends',
#  'exonerate-Forgive/Make_Amends',
#  'expiate-Forgive/Make_Amends',
#  'palliate-Forgive/Make_Amends',
#  'redress-Forgive/Make_Amends',
#  'vindicate-Forgive/Make_Amends',
#  'chortle-Funny',
#  'droll-Funny',
#  'facetious-Funny',
#  'flippant-Funny',
#  'gibe-Funny',
#  'jocular-Funny',
#  'levity-Funny',
#  'ludicrous-Funny',
#  'raillery-Funny',
#  'riposte-Funny',
#  'abatement-Gaps/Openings',
#  'aperture-Gaps/Openings',
#  'fissure-Gaps/Openings',
#  'hiatus-Gaps/Openings',
#  'interregnum-Gaps/Openings',
#  'interstice-Gaps/Openings',
#  'lull-Gaps/Openings',
#  'orifice-Gaps/Openings',
#  'rent-Gaps/Openings',
#  'respite-Gaps/Openings',
#  'rift-Gaps/Openings',
#  'altruistic-Generous/Kind',
#  'beneficent-Generous/Kind',
#  'clement-Generous/Kind',
#  'largess-Generous/Kind',
#  'magnanimous-Generous/Kind',
# ...
